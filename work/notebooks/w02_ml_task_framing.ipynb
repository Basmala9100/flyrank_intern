# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# My selected lane is **Refresh / Content Opportunity Scoring**.
#
# This is primarily a **classification and scoring** problem.
#
# The classification model estimates whether a content page is likely to require a review, while the scoring component ranks pages by their priority so the content team knows which pages to review first.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# For the starter dataset, I will use **is_declining_label** as the target.
#
# This proxy label identifies whether a page is showing a declining trend based on the available data. Although it is not a future outcome, it provides a suitable starting point for learning and evaluating the workflow.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# The primary success metric is **Precision@50**.
#
# This metric measures how many of the top-ranked pages actually require review. Since content teams have limited time, ranking the most useful pages first is more valuable than maximizing overall accuracy.
#
# I will also monitor ROC-AUC and Average Precision to evaluate overall model performance.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

df = pd.read_csv("/content/content_refresh_anonymized.csv")

df.head()
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
df.shape
# Out:
# (30000, 44)

# %%
df[['content_id',
    'impressions_90d',
    'clicks_90d',
    'sessions_90d',
    'trend_direction']].head()
# Out:
#              content_id  impressions_90d  clicks_90d  sessions_90d  \
# 0  content_304f48230142             3803          29            17
# 1  content_a1fb4e703a9e            15320           7             9
# 2  content_9aa793d4d895            12581          11            11
# 3  content_331d6c4de07b            11751          58            78
# 4  content_d99b7a2d90ca            19140          24           145
#
#   trend_direction
# 0            down
# 1            down
# 2            down
# 3          stable
# 4            down

# %% [markdown]
# The unit of analysis is **one content page**.
#
# Each row in the dataset represents a single content page together with its search performance, engagement metrics, and content characteristics.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A fixed rule may rely on one or two conditions, such as low CTR or old content age.
#
# However, content performance is influenced by multiple interacting factors, including impressions, clicks, CTR, search position, freshness, engagement, and content characteristics.
#
# Machine learning can combine these signals to identify complex patterns and prioritize pages more effectively than a single manually designed rule.
#
# The model supports human decision-making by producing a ranked list of review candidates rather than replacing human judgment.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
